# %%
from zeni.basic_types import Addressable
Addressable(["a",1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 from zeni.basic_types import Addressable
# ----> 2 Addressable(["a",1])
#
# File ~/Code/Personal/zeni/src/zeni/basic_types.py:86, in Addressable.__init__(self, iterable)
#      84 self.iterable = iterable
#      85 for item in self.iterable:
# ---> 86     attr_name = item.replace(" ", "_").replace("-", "_")
#      87     if attr_name.isidentifier():
#      88         setattr(self, attr_name, item)
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
import pandas as pd

monzo = pd.read_csv("data/samples/monzo.csv")

# %%
set(monzo["Category"].values)
# Out:
# {'Bills',
#  'Eating out',
#  'Entertainment',
#  'General',
#  'Groceries',
#  'Income',
#  'Personal care',
#  'Savings',
#  'Shopping',
#  'Transfers'}

# %%
monzo[monzo["Type"] == 'Monzo-to-Monzo']
# Out:
#                Transaction ID        Date      Time            Type  \
# 20  tx_0000AuBvAVTqvNsXRQAkjp  17/05/2025  17:02:50  Monzo-to-Monzo
# 23  tx_0000AuJmn6QWf7EBQNXCj3  21/05/2025  12:06:40  Monzo-to-Monzo
#
#                  Name Emoji Category  Amount Currency  Local amount  \
# 20  Eleanor Hutchison   NaN  General     5.0      GBP           5.0
# 23     Caitlin Fearon   NaN  General    35.0      GBP          35.0
#
#    Local currency Notes and #tags Address  Receipt Description  \
# 20            GBP             NaN     NaN      NaN         NaN
# 23            GBP             NaN     NaN      NaN         NaN
#
#     Category split  Money Out  Money In
# 20             NaN        NaN       5.0
# 23             NaN        NaN      35.0

# %%
monzo[monzo["Category"] == "Bills"]
# Out:
#                Transaction ID        Date      Time          Type     Name  \
# 1   tx_0000AtdScAqXjPDtOMWUOP  01/05/2025  02:01:58  Direct Debit    Etika
# 14  tx_0000AtqekR6kscrWE5dnxS  07/05/2025  10:49:55  Card payment  Spotify
# 31  tx_0000Auhv6WnSJ3SxqiXAOH  02/06/2025  03:32:53  Direct Debit    Etika
# 36  tx_0000AusugAZqQtTSf8QgcN  07/06/2025  10:49:57  Card payment  Spotify
# 52  tx_0000AvfzJioYzcrGYFXKV8  01/07/2025  03:02:46  Direct Debit    Etika
# 55  tx_0000Avt65qeYHHDTIZIvjN  07/07/2025  10:49:57  Card payment  Spotify
#
#    Emoji Category  Amount Currency  Local amount Local currency  \
# 1    NaN    Bills   -9.50      GBP         -9.50            GBP
# 14     🎵    Bills  -11.99      GBP        -11.99            GBP
# 31   NaN    Bills   -9.50      GBP         -9.50            GBP
# 36     🎵    Bills  -11.99      GBP        -11.99            GBP
# 52   NaN    Bills   -9.50      GBP         -9.50            GBP
# ...

# %%
parsed = parse_monzo(monzo)

# %%
parsed
# Out:
#    StandardColumns.DATE StandardColumns.TIME StandardColumns.TYPE  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# ..                  ...                  ...                  ...
# 73                  NaN                  NaN                  NaN
# 74                  NaN                  NaN                  NaN
# 75                  NaN                  NaN                  NaN
# 76                  NaN                  NaN                  NaN
# 77                  NaN                  NaN                  NaN
#
#    StandardColumns.CATEGORY StandardColumns.NAME StandardColumns.AMOUNT  \
# 0                       NaN                  NaN                    NaN
# ...

# %%
from zeni.parse.parser import PERFERRED_ORDERING

PERFERRED_ORDERING
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from zeni.parse.parser import PERFERRED_ORDERING
#       2 PERFERRED_ORDERING
#
# File ~/Code/Personal/zeni/src/zeni/parse/parser.py:15
#      11 if TYPE_CHECKING:
#      12     from zeni.parse.banks.base import Bank
# ---> 15 PERFERRED_ORDERING = tuple(
#      16     map(
#      17         partial(getattr, name="value"),
#      18         (
#      19             StandardColumns.DATE,
#      20             StandardColumns.TIME,
#      21             StandardColumns.TYPE,
#      22             StandardColumns.CATEGORY,
#      23             StandardColumns.NAME,
#      24             StandardColumns.AMOUNT,
#      25             StandardColumns.CURRENCY,
#      26         ),
#      27     )
#      28 )
#      31 class Parse:
#      32     """Parse a CSV file into a standardised format."""
#
# ...

# %%
from zeni.types import StandardColumns

("value",) * len(StandardColumns)
# Out:
# ('value', 'value', 'value', 'value', 'value', 'value', 'value')
